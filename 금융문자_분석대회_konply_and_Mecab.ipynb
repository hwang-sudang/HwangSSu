# %% [markdown]
# <a href="https://colab.research.google.com/github/hwang-sudang/HwangSSu/blob/master/%EA%B8%88%EC%9C%B5%EB%AC%B8%EC%9E%90_%EB%B6%84%EC%84%9D%EB%8C%80%ED%9A%8C_konply_and_Mecab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
train_data = pd.read_csv('/content/drive/My Drive/Smishing/train.csv', encoding='cp949')

# %%
traindata1=pd.DataFrame(train_data["text"])
traindata1
# Out:
#                                                      text
# 0                                XXX은행성산XXX팀장입니다.행복한주말되세요
# 1                   오늘도많이웃으시는하루시작하세요XXX은행 진월동VIP라운지 XXX올림
# 2       안녕하십니까 고객님. XXX은행입니다.금일 납부하셔야 할 금액은 153600원 입니...
# 3       XXX 고객님안녕하세요XXX은행 XXX지점입니다지난 한 해 동안 저희 XXX지점에 ...
# 4                1월은 새로움이 가득XXX입니다.올 한해 더 많이행복한 한해되시길바랍니다
# ...                                                   ...
# 295940  XXX 고객님!열심히 달려왔던 2018년도 어느 새 뒤안길로 지나쳐가고 벅찬 설렘으...
# 295941                  XXX고객님실버웰빙신탁이 만기도래 예정입니다.XXX남양주지점
# 295942  한해동안 XXX은행과 함께 해주셔서 정말 감사드립니다 2019년 기해년을 맞이하며 ...
# 295943  1228(금)예금및 적금 만기입니다.예금은 시간내서 내점하시고 적금은 1년 자동연장...
# 295944  안녕하세요 XXX 고객님. 스타링크 전담직원 XXX입니다. 스타링크 고객님 대상으로...
#
# [295945 rows x 1 columns]

# %% [markdown]
# ##### smishing 여부 0,1인 것 분리

# %%
train_data
# Out:
#             id  ... smishing
# 0            0  ...        0
# 1            1  ...        0
# 2            2  ...        0
# 3            4  ...        0
# 4            5  ...        0
# ...        ...  ...      ...
# 295940  336373  ...        0
# 295941  336375  ...        0
# 295942  336376  ...        0
# 295943  336377  ...        0
# 295944  336378  ...        0
#
# [295945 rows x 4 columns]

# %%
smishing_1=pd.DataFrame(train_data[train_data["smishing"]==1]["text"])
smishing_0=pd.DataFrame(train_data[train_data["smishing"]!=1]["text"])
smishing_1
# Out:
#                                                      text
# 9       (광고)XXXBaXXX고객님들 뒤엔XXX 언제나 XXX새로운 마음가짐으로 새롭게 준...
# 23      (광고)XXX추가 XXX품   특판 안내문XXX 지점에서 취급하고 있는 여신 XXX...
# 31      (광고)XXX신용관리 XXX 알고 싶다나의 신용과 재무상태는 직접 관리해야지 누군가...
# 40      (광고)안녕하세요수신을 희망하지 않으실 경우에는 거부 라는 답장을 주시면 KISA ...
# 50      (광고)한국citi bank 나의 대출한도와 금리는? 대출때문에 고민하고 있다거나 ...
# ...                                                   ...
# 295927  (광고)XXX금전을 요구하는건 사기입니다. 유의하세요!1.부득이하게 높은 이자를 내...
# 295932  (광고)XXX금전을 요구하는건 사기입니다. 유의하세요!1.부득이하게 높은 이자를 내...
# 295934  (광고)XXX나의 한도금리를 알아보자금전을 요구하는건 사기입니다. 유의하세요!1.부...
# 295936  (광고) XXX항상 (XXX국민)은행을 이용해주셔서 감사합니다. 2018년 12월 ...
# 295937  (광고)XXX가이드 변경 안내정확하고 올바른 신용상품 당사상품의 자격기준과 심사기준...
#
# [18703 rows x 1 columns]

# %% [markdown]
# # 한국어 불용어 처리 - KonPLy , Mecab

# %% [markdown]
# 현재 다양한 자연어 처리 패키지 중에서 mecab는 윈도우에서는 설치가 힘든 패키지 중 하나이다.
#
# 이를 극복하기 위해, colab에서 mecab를 설치하고 활용할 수 있도록 colab 파일을 공유하고자 한다.

# %% [markdown]
# ##### Konply, Mecab 설치

# %%
! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 47 (delta 16), reused 20 (delta 5), pack-reused 0
# Unpacking objects: 100% (47/47), done.

# %%
ls
# Out:
# drive/  Mecab-ko-for-Google-Colab/  sample_data/

# %%
cd Mecab-ko-for-Google-Colab/
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
ls
# Out:
# images/  install_mecab-ko_on_colab190912.sh  README.md

# %%
! bash install_mecab-ko_on_colab190912.sh
# Out:
# Installing konlpy.....
# ...
#      |████████████████████████████████| 19.4MB 230kB/s
# ...
#      |████████████████████████████████| 92kB 10.5MB/s
# ...
#      |████████████████████████████████| 491kB 62.0MB/s
# ...
#   Created wheel for JPype1: filename=JPype1-0.7.1-cp36-cp36m-linux_x86_64.whl size=2436137 sha256=335f69e35b7e2251118b2b345655d5390446e6e982c32d16f7a95a0b75b7351a
#   Stored in directory: /root/.cache/pip/wheels/b0/49/6a/4393ef8542c00becf80691bd242693db9e263d6e499323a984
# Successfully built JPype1
# ...
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %%
import konlpy
from konlpy.tag import Mecab

tokenizer = Mecab() # setting tokenizer using Mecab()

# %% [markdown]
# ##### 모든 데이터 가지고 오면 과부하걸려서 일단은 sampling

# %%
# 필요한 라이브러리, 모듈
import pandas as pd # 데이터 전처리
import numpy as np # 데이터 전처리
import random #데이터 전처리
from pandas import DataFrame #데이터 전처리
from collections import Counter #데이터 전처리

from tqdm import tqdm #시간 측정용

from sklearn.feature_extraction.text import CountVectorizer # model setting
from sklearn.model_selection import train_test_split  # model setting

from sklearn.naive_bayes import MultinomialNB  # model 관련
from sklearn.metrics import roc_auc_score  # model 성능 확인

# %%
850/12600
# Out:
# 0.06746031746031746

# %% [markdown]
# #### undersampling 위해서 지금 trian , test 데이터 나누는중

# %%
random.seed(2019) #반복 수행시에도 동일한 결과 나올 수 있도록 시드 번호 지정
train_nsm_list=list(train_data[train_data['smishing']!=1].index)
train_nsmishing=random.sample(train_nsm_list, 11750 )

random.seed(2019)
train_sm_list=list(train_data[train_data['smishing']==1].index)
train_smishing=random.sample(train_sm_list, 850 ) #0.066과 제일 비슷하게 나올 수 있도록  train data under sampling

# %%
train_xx=train_data.iloc[train_smishing+train_nsmishing,:].reset_index(drop=True) #under sampling으로 나온 index들로 train data 선별

train_yy=DataFrame(train_data['smishing'],columns=['smishing']) 
train_yyy=train_yy.iloc[train_smishing+train_nsmishing,:].reset_index(drop=True)

# %%
train_xx
# Out:
#            id  ... smishing
# 0      178368  ...        1
# 1      222915  ...        1
# 2      320171  ...        1
# 3      183747  ...        1
# 4      223520  ...        1
# ...       ...  ...      ...
# 12595  208409  ...        0
# 12596  145270  ...        0
# 12597  318400  ...        0
# 12598   22081  ...        0
# 12599  110045  ...        0
#
# [12600 rows x 4 columns]

# %%
test = pd.read_csv("/content/drive/My Drive/Smishing/public_test.csv",encoding="cp949")

test.head(2)
# Out:
#        id year_month                                               text
# 0  340000    2019-01  XXX고객님! 안녕하세요? 새롭게 시작하는 한 주 행복 가득하시길 기원합니다. 지난...
# 1  340001    2019-01   긴급 안내  XXX은행 가락동 지점  - 헬리오XXX 기본XXX    대출이자를 ...

# %%
test['smishing']=2 #train data와 동일한 형태 생성을 위해 임의의 숫자를 추가 #이후 스미싱 여부 확률 값으로 덮어 씌워짐
test_xx=DataFrame(test['text'])
test_yyy=DataFrame(test['smishing'])

# %%
train_xx.shape,train_yyy.shape,test_xx.shape,test_yyy.shape
# Out:
# ((12600, 4), (12600, 1), (1626, 1), (1626, 1))

# %%
train_xx['text'][0]
# Out:
# '(광고) S B I XXX XXX안녕하세요하루하루 힘든업무와 스트레스에 고생많으십니다여유시간을 내어 읽어 주신다면 도움이 되실거라 생각되어 XXX을 보내드립니다2017년 하반기 정부지원 상품이 개편되어 안내드립니다금년 낮은 금리로 대출금 이용하실수 있는 마지막 기회입니다.고민하지 마시고 전화주세요본상품은 서민지원대출로 정부에서 지원하고S B I XXX에서 판매하는대출상품입니다.상품특징1.무담보! 무보증! 무수수료!2.신용등급상관없이3.최고한도 90004.최하금리4.24%  9.89%5.상환수수료 없이 자유롭게 상환가능!6.기존대출 저금리 전환가능자격조건1.만21세65세2.직장인.사업자.프리랜서.주부3.최근부결자.다중채무자 가능신청기간9월29일마감.접수자가 많으니 빠른신청 바랍니다신청방법상담 가능하실때 카톡추가.또는 전화주시면 상담가능하십니다상담전화XXX-XXX-XXX카카오톡문의 아이디 bb745 입니다해당이 되지 않으시거나 거부를 원하시는 분들은 거부라고 회신하여 주신다면 재발송 않도록 하겠습니다 번호의 오류나 전산의 실수가 있을 수 있사오니 양해 부탁드립니다무료거부 XXX-XXX-XXX(광고)S B I XXX XXX'

# %% [markdown]
# ## Mecab() 활용하여 토큰화시키자.
# - Tokernize = Mecab()
# - 불용어 거르는 과정. det get_couple

# %%
train_doc_0 = [( tokenizer.pos(x) ) for x in tqdm(smishing_0['text'])]
# Out:
# 100%|██████████| 277242/277242 [01:28<00:00, 3131.91it/s]

# %%
train_doc_1 = [ ( tokenizer.pos(x) ) for x in tqdm(smishing_1['text'])] # Mecab를 활용하여 text를 토큰화 시킴
# Out:
# 100%|██████████| 18703/18703 [00:35<00:00, 529.11it/s]

# %%
test_doc = [ ( tokenizer.pos(x), y ) for x, y in tqdm( zip( test_xx['text'], test_yyy['smishing'] ) )  ]
# Out:
# 1626it [00:01, 1529.36it/s]

# %% [markdown]
# ##### train_doc가 어떻게 생겼고, 모든 데이터 가지고왓는지 잠깐 확인

# %%
type(train_doc_0)
# Out:
# list

# %%
len(train_doc_0) #스미싱 아닌거 갯수맞음.
# Out:
# 277242

# %%
train_doc_1[0]
# Out:
# [('(', 'SSO'),
#  ('광고', 'NNG'),
#  (')', 'SSC'),
#  ('XXXBaXXX', 'SL'),
#  ('고객', 'NNG'),
#  ('님', 'XSN'),
#  ('들', 'XSN'),
#  ('뒤', 'NNG'),
#  ('엔', 'JKB+JX'),
#  ('XXX', 'SL'),
#  ('언제나', 'MAG'),
#  ('XXX', 'SL'),
#  ('새로운', 'VA+ETM'),
#  ('마음가짐', 'NNG'),
#  ('으로', 'JKB'),
#  ('새롭', 'VA'),
#  ('게', 'EC'),
#  ('준비', 'NNG'),
#  ('합니다', 'XSV+EF'),
#  ('.', 'SF'),
#  ('당', 'NNG'),
#  ('행상', 'NNG'),
#  ('품', 'NNG'),
#  ('의', 'JKG'),
#  ('자격', 'NNG'),
#  ('기준', 'NNG'),
#  ('과', 'JC'),
#  ('심사', 'NNG'),
#  ('기준', 'NNG'),
#  ('이', 'JKS'),
#  ('완화', 'NNG'),
#  ('되', 'XSV'),
#  ('어', 'EC'),
#  ('상품', 'NNG'),
#  ('에', 'JKB'),
#  ('대해', 'VV+EC'),
#  ('간단', 'XR'),
#  ('하', 'XSA'),
#  ('게', 'EC'),
#  ('상품', 'NNG'),
#  ('정보', 'NNG'),
#  ('전달', 'NNG'),
#  ('드립니다', 'VV+EF'),
#  ('.', 'SF'),
#  ('수신', 'NNG'),
#  ('을', 'JKO'),
#  ('희망', 'NNG'),
#  ('하', 'XSA'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('으실', 'EP+ETM'),
#  ('경우', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('거부', 'NNG'),
# ...

# %% [markdown]
# ### list flatten

# %%
import itertools
def chain(*iterables):
    # chain('ABC', 'DEF') --> ['A', 'B', 'C', 'D', 'E', 'F']
    for it in iterables:
        for element in it:
            yield element

# %%
train1_list=list(itertools.chain(*train_doc_1))
train0_list=list(itertools.chain(*train_doc_0))

# %%
print(train1_list[0],sep="")
# Out:
# ('(', 'SSO')

# %%
train1_list # 각 [(메세지('단어', '타입'))] 이런형태로 뱉아냄
# Out:
# [('(', 'SSO'),
#  ('광고', 'NNG'),
#  (')', 'SSC'),
#  ('XXXBaXXX', 'SL'),
#  ('고객', 'NNG'),
#  ('님', 'XSN'),
#  ('들', 'XSN'),
#  ('뒤', 'NNG'),
#  ('엔', 'JKB+JX'),
#  ('XXX', 'SL'),
#  ('언제나', 'MAG'),
#  ('XXX', 'SL'),
#  ('새로운', 'VA+ETM'),
#  ('마음가짐', 'NNG'),
#  ('으로', 'JKB'),
#  ('새롭', 'VA'),
#  ('게', 'EC'),
#  ('준비', 'NNG'),
#  ('합니다', 'XSV+EF'),
#  ('.', 'SF'),
#  ('당', 'NNG'),
#  ('행상', 'NNG'),
#  ('품', 'NNG'),
#  ('의', 'JKG'),
#  ('자격', 'NNG'),
#  ('기준', 'NNG'),
#  ('과', 'JC'),
#  ('심사', 'NNG'),
#  ('기준', 'NNG'),
#  ('이', 'JKS'),
#  ('완화', 'NNG'),
#  ('되', 'XSV'),
#  ('어', 'EC'),
#  ('상품', 'NNG'),
#  ('에', 'JKB'),
#  ('대해', 'VV+EC'),
#  ('간단', 'XR'),
#  ('하', 'XSA'),
#  ('게', 'EC'),
#  ('상품', 'NNG'),
#  ('정보', 'NNG'),
#  ('전달', 'NNG'),
#  ('드립니다', 'VV+EF'),
#  ('.', 'SF'),
#  ('수신', 'NNG'),
#  ('을', 'JKO'),
#  ('희망', 'NNG'),
#  ('하', 'XSA'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('으실', 'EP+ETM'),
#  ('경우', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('거부', 'NNG'),
# ...

# %%
train_meaning=pd.DataFrame(train1_list)
train_meaning  #이제 품사보고 불용어 거르는 일만 남음 Yo
# Out:
#                 0      1
# 0               (    SSO
# 1              광고    NNG
# 2               )    SSC
# 3        XXXBaXXX     SL
# 4              고객    NNG
# ...           ...    ...
# 7559906       XXX     SL
# 7559907        투안    NNG
# 7559908         녕    NNG
# 7559909         하    XSV
# 7559910        세요  EP+EF
#
# [7559911 rows x 2 columns]

# %% [markdown]
# #####품사대비 드랍

# %% [markdown]
# ['SSO', 'SSC', 'SL', 'XSN', 'JKB+JX', 'VA+ETM', 'JKB','VA', 'EC', 'XSV+EF', 'SF', 'JKG', 'JC', 'JKS', 'XSV', 'XR', 'XSA', 'JKO', 'VX', 'EP+ETM', 'JX', 'VCP+ETM','EP',, 'EF', 'SC', 'SY', 'EP+EC', 'SN', 'VCP', 'XSA+ETM', 'VX+EF', 'XPN', 'ETM', 'EP+EP', 'NR',
# 'XSV+EC', 'JKC', 'VCN+EF', 'ETN', 'VCP+EF','VX+ETM', 'VCP+EC', 'EP+EF', 'ETN+VCP+EF', 'VX+EP','VA+ETN', 'VCN', 'XSV+ETM', 'XSA+EF','UNKNOWN', 'XSV+EP', 'EP+EP+ETM','EP+EP+EC', 'XSV+ETN', 'VX+EP+EC', 'EP+EP+EF', 'VX+EC','EP+EF+VCP', 'ETN+JKO', 'VCP+EP+EF', 'XSA+EC', 'NNB+JX', 'VA+EP+EF', 'VCN+ETN',
# 'XSA+EC+VX+ETM', 'VA+EF','JKQ', 'ETN+ETM', 'VA+EC', 'EP+NA','VCP+EP', 'VA+EC+VX+EP', 'VX+EP+EF','EC+XSV+ETM', 'XSA+ETN', 'EC+VX+EF', 'VCN+ETM', 'VA+EP+ETM','EC+VX+EC', 'VX+EC+VX+ETM', 'VA+ETN+JKB+JX','VA+EP', 'EC+JX', 'EP+EC+VX+EC','JKB+JKO', 'JKS+EP+EC' 'VX+ETN',
# 'VCP+ETN', 'XSA+EC+VX+EP', 'XSV+EC+VCP', 'VA+EC+VX+EC','VA+EC+VX+ETM', 'JX+ETM', 'JKV', 'VA+JX']

# %%
stopwords=["NR","VA","VX","VCP",'VCN','JSK','JKC','JKG','JKO','JKB','JKV','JKQ','JC','JX','EP',
           'EF','EC','ETN','ETM','XPN','XSN','XSV','XSA','SF','SE','SS','SP','SO','SW',
           'SH','SL','SN','SSO',"SSC"]

# %%
train_meaning[1].unique()
# Out:
# array(['SSO', 'NNG', 'SSC', 'SL', 'XSN', 'JKB+JX', 'MAG', 'VA+ETM', 'JKB',
#        'VA', 'EC', 'XSV+EF', 'SF', 'JKG', 'JC', 'JKS', 'XSV', 'VV+EC',
#        'XR', 'XSA', 'VV+EF', 'JKO', 'VX', 'EP+ETM', 'JX', 'VCP+ETM', 'VV',
#        'EP', 'MM', 'NNBC', 'EF', 'SC', 'SY', 'EP+EC', 'MAJ', 'SN', 'VCP',
#        'XSA+ETM', 'NNP', 'NNB', 'VX+EF', 'XPN', 'ETM', 'EP+EP', 'NR',
#        'XSV+EC', 'VV+ETM', 'NP', 'JKC', 'VCN+EF', 'ETN', 'VCP+EF',
#        'VX+ETM', 'VCP+EC', 'EP+EF', 'NNG+JC', 'ETN+VCP+EF', 'VX+EP',
#        'NNB+VCP+EC', 'VA+ETN', 'VCN', 'VV+EP', 'XSV+ETM', 'XSA+EF',
#        'VX+ETM+NNB+JX', 'UNKNOWN', 'XSV+EP', 'EP+EP+ETM', 'NNB+JKS',
#        'EP+EP+EC', 'XSV+ETN', 'NNB+JKC', 'VX+EP+EC', 'EP+EP+EF', 'VX+EC',
#        'EP+EF+VCP', 'ETN+JKO', 'IC', 'VCP+EP+EF', 'XSA+EC', 'VV+EC+VX+EC',
#        'VV+ETM+NNB+JKO', 'NNB+JKB', 'NNB+JX', 'VA+EP+EF', 'VCN+ETN',
#        'XSA+EC+VX+ETM', 'NP+JKG', 'NP+VCP+EC', 'NNB+JKO', 'VA+EF',
# ...

# %%
type(train_meaning[1])
# Out:
# pandas.core.series.Series

# %%
y=[]
[y.append(x) for x in train_meaning[1].item if x not in stopwords]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-1fcbf8ab2261> in <module>()
#       1 y=[]
# ----> 2 [y.append(x) for x in train_meaning[1].item if x not in stopwords]
#
# TypeError: 'method' object is not iterable

# %%
def get_couple(_words): #필요없는 단어들 없애는 함수
    global stopwords
    _words = [x for x in _words if x[0] not in stopwords]
    l = len(_words)
    for i in range(l-1):
        yield _words[i][0], _words[i+1][0]

# %%
# boolean Index #train_meaning
train_meaning.drop(train_meaning[train_meaning[1].item in stopwords])

# %% [markdown]
# ### 잠깐! 불용어는 아직 기다려봐

# %%
stopwords = ['XXX', '.', '을', '를', '이', '가', '-', '(', ')', ':', '!', '?', ')-', '.-', 'ㅡ', 'XXXXXX', '..', '.(', '은', '는'] #필요없는 단어 리스트

def get_couple(_words): #필요없는 단어들 없애는 함수
    global stopwords
    _words = [x for x in _words if x[0] not in stopwords]
    l = len(_words)
    for i in range(l-1):
        yield _words[i][0], _words[i+1][0]
